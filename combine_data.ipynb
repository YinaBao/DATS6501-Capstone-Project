# %%
import pandas as pd

training = pd.read_csv('selected_train.csv')
testing = pd.read_csv('selected_test.csv')

# %%
print(training)
# Out:
#         Unnamed: 0  star_rating  \
# 0                0            1
# 1                1            1
# 2                2            1
# 3                3            1
# 4                4            1
# 5                5            1
# 6                6            1
# 7                7            1
# 8                8            1
# 9                9            1
# 10              10            1
# 11              11            1
# 12              12            1
# 13              13            1
# 14              14            1
# 15              15            1
# 16              16            1
# 17              17            1
# 18              18            1
# 19              19            1
# 20              20            1
# 21              21            1
# 22              22            1
# 23              23            1
# 24              24            1
# 25              25            1
# 26              26            1
# 27              27            1
# ...

# %%
training = training.drop(['Unnamed: 0'],axis = 1)
testing = testing.drop(['Unnamed: 0'],axis = 1)

# %%
df = testing.append(training)

# %%
df
# Out:
#         star_rating                                           headline  \
# 0               1.0                                 all hype no talent
# 1               1.0     ugly american read where is canada and britain
# 2               1.0                     it s not techno nor good music
# 3               1.0                            extremely disappointing
# 4               1.0              this humidifier will make you go deaf
# 5               1.0                        good hook no clips or bolts
# 6               1.0                            not backed by whirlpool
# 7               1.0                          you ve lost the plot dude
# 8               1.0                                  worst vacuum ever
# 9               1.0                                                yuk
# 10              1.0                             don t believe the hype
# 11              1.0                              what a disappointment
# ...

# %%
df.reset_index(inplace=True)

# %%
df = df.drop("index",axis=1)

# %%
df
# Out:
#         star_rating                                           headline  \
# 0               1.0                                 all hype no talent
# 1               1.0     ugly american read where is canada and britain
# 2               1.0                     it s not techno nor good music
# 3               1.0                            extremely disappointing
# 4               1.0              this humidifier will make you go deaf
# 5               1.0                        good hook no clips or bolts
# 6               1.0                            not backed by whirlpool
# 7               1.0                          you ve lost the plot dude
# 8               1.0                                  worst vacuum ever
# 9               1.0                                                yuk
# 10              1.0                             don t believe the hype
# 11              1.0                              what a disappointment
# ...

# %%
df.to_csv("clean_combined_data.csv")

# %%
clean_data = pd.read_csv('clean_combined_data.csv')

# %%
clean_data
# Out:
#         Unnamed: 0  star_rating  \
# 0                0          1.0
# 1                1          1.0
# 2                2          1.0
# 3                3          1.0
# 4                4          1.0
# 5                5          1.0
# 6                6          1.0
# 7                7          1.0
# 8                8          1.0
# 9                9          1.0
# 10              10          1.0
# 11              11          1.0
# 12              12          1.0
# 13              13          1.0
# 14              14          1.0
# 15              15          1.0
# 16              16          1.0
# 17              17          1.0
# 18              18          1.0
# 19              19          1.0
# 20              20          1.0
# 21              21          1.0
# 22              22          1.0
# 23              23          1.0
# 24              24          1.0
# 25              25          1.0
# 26              26          1.0
# 27              27          1.0
# ...
